# %% [markdown]
# <a href="https://colab.research.google.com/github/soumya17052002/Document-Digitisation/blob/main/Image_Proc_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import PIL
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/content/TestImage.jpg')

# %%
image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
image_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
canny_image=cv2.Canny(image,100,200)
plt.imshow(canny_image)

# %%
im2, contours = cv2.findContours(canny_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(contours)
# Out:
# [[[   1   -1   -1   -1]
#   [   2    0   -1   -1]
#   [   4    1    3   -1]
#   ...
#   [2172 2170   -1   -1]
#   [2173 2171   -1   -1]
#   [  -1 2172   -1   -1]]]

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-3c23ae429e79> in <module>()
# ----> 1 cv2.drawContours(image, contours, 3, (0,255,0), 3)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/drawing.cpp:2498: error: (-215:Assertion failed) 0 <= contourIdx && contourIdx < (int)last in function 'drawContours'
